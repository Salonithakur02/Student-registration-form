# %%
# Student Registration Form – Advanced Web Design

# %%
## Objective
The objective of this project is to design and develop a responsive and user-friendly Student Registration Form using HTML, CSS, and JavaScript.

# %%
## Dataset Source
This project does not use a dataset. The input is manually provided by the user via the registration form fields.

# %%
## Steps Performed
1. Designed the structure using HTML.
2. Styled the webpage using CSS.
3. Added form validation using JavaScript.
4. Tested and debugged the form.
5. Hosted the files on GitHub.

# %%
## Key Results
- A clean, professional, and responsive registration form.
- Successful validation of all fields.
- Easy-to-understand user interface.
- Error-free functioning across browsers.
